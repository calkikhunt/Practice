# %%
import pandas as pd
import numpy as np
# check diffreance analysis approach in below link.
# https://datascience.fm/pandas-for-simple-data-analysys/

# %%
# df = pd.read_table("https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv")
df = pd.read_csv("https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv", sep="\t")
df.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
df['item_price'] = list(map(lambda l: float(l[1:]), df['item_price'].values))

# %%
df.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description  item_price
# 0                                                NaN        2.39
# 1                                       [Clementine]        3.39
# 2                                            [Apple]        3.39
# 3                                                NaN        2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98

# %%
df['total_price'] = df['quantity'] * df['item_price']

# %%
df.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description  item_price  total_price
# 0                                                NaN        2.39         2.39
# 1                                       [Clementine]        3.39         3.39
# 2                                            [Apple]        3.39         3.39
# 3                                                NaN        2.39         2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98        33.96

# %%
df.groupby("order_id")['item_name'].unique().astype(str).value_counts()
# Out:
# ['Chicken Bowl' 'Chips and Guacamole']                                             68
# ['Chicken Bowl']                                                                   61
# ['Chicken Burrito']                                                                51
# ['Chicken Burrito' 'Chips and Guacamole']                                          37
# ['Steak Burrito' 'Chips and Guacamole']                                            26
#                                                                                    ..
# ['Veggie Burrito' 'Carnitas Crispy Tacos']                                          1
# ['Barbacoa Bowl' 'Veggie Bowl']                                                     1
# ['Veggie Burrito' 'Veggie Crispy Tacos']                                            1
# ['Chicken Burrito' 'Chicken Soft Tacos'\n 'Chips and Roasted Chili Corn Salsa']     1
# ['Carnitas Bowl' 'Chips' 'Bottled Water']                                           1
# ...

# %%
df.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description  item_price  total_price
# 0                                                NaN        2.39         2.39
# 1                                       [Clementine]        3.39         3.39
# 2                                            [Apple]        3.39         3.39
# 3                                                NaN        2.39         2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98        33.96

# %%
df.merge(df, on='order_id')
# Out:
#        order_id  quantity_x                   item_name_x  \
# 0             1           1  Chips and Fresh Tomato Salsa
# 1             1           1  Chips and Fresh Tomato Salsa
# 2             1           1  Chips and Fresh Tomato Salsa
# 3             1           1  Chips and Fresh Tomato Salsa
# 4             1           1                          Izze
# ...         ...         ...                           ...
# 14285      1834           1            Chicken Salad Bowl
# 14286      1834           1            Chicken Salad Bowl
# 14287      1834           1            Chicken Salad Bowl
# 14288      1834           1            Chicken Salad Bowl
# 14289      1834           1            Chicken Salad Bowl
#
#                                     choice_description_x  item_price_x  \
# 0                                                    NaN          2.39
# 1                                                    NaN          2.39
# ...

# %%
df.tail()
# Out:
#       order_id  quantity           item_name  \
# 4617      1833         1       Steak Burrito
# 4618      1833         1       Steak Burrito
# 4619      1834         1  Chicken Salad Bowl
# 4620      1834         1  Chicken Salad Bowl
# 4621      1834         1  Chicken Salad Bowl
#
#                                      choice_description  item_price  \
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...       11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...       11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...       11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...        8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...        8.75
#
#       total_price
# 4617        11.75
# 4618        11.75
# 4619        11.25
# 4620         8.75
# 4621         8.75

# %%
df1 = df.reset_index()
df1 = df1.merge(df1, on='order_id').query('index_x > index_y')
df1 = pd.DataFrame(np.sort(df1[['item_name_x', 'item_name_y']].to_numpy(), axis=1))
df1.groupby([*df1]).size().sort_values(ascending=False)
# Out:
# 0                                   1
# Chicken Bowl                        Chips and Guacamole                    179
#                                     Chicken Bowl                           164
#                                     Chicken Burrito                        155
#                                     Chips                                  143
# Canned Soft Drink                   Chicken Bowl                           134
#                                                                           ...
# Chips and Guacamole                 Chips and Roasted Chili Corn Salsa       1
# Barbacoa Soft Tacos                 Steak Soft Tacos                         1
#                                     Steak Bowl                               1
#                                     Chips and Roasted Chili Corn Salsa       1
# Chips and Roasted Chili-Corn Salsa  Chips and Tomatillo-Red Chili Salsa      1
# Length: 518, dtype: int64

# %% [markdown]
# ## how many products cost more than 10$?

# %%
df2 = pd.read_csv("https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv", sep="\t")
df2.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
df2['price_float'] = pd.to_numeric(df2.item_price.str.slice(1))

# %%
(df2['price_float'] > 10).sum()
# Out:
# 1130

# %%
product_prices = df2.groupby("item_name").agg({'price_float': 'max'})
(product_prices.price_float > 10).sum()
# Out:
# 31

# %% [markdown]
# # what is a price of each item?

# %%
product_prices.head()
# Out:
#                        price_float
# item_name
# 6 Pack Soft Drink            12.98
# Barbacoa Bowl                11.75
# Barbacoa Burrito             11.75
# Barbacoa Crispy Tacos        18.50
# Barbacoa Salad Bowl          11.89

# %% [markdown]
# # sort by the name of the item?

# %%
df2.sort_values("item_name").head()
# Out:
#       order_id  quantity          item_name choice_description item_price  \
# 3389      1360         2  6 Pack Soft Drink        [Diet Coke]    $12.98
# 341        148         1  6 Pack Soft Drink        [Diet Coke]     $6.49
# 1849       749         1  6 Pack Soft Drink             [Coke]     $6.49
# 1860       754         1  6 Pack Soft Drink        [Diet Coke]     $6.49
# 2713      1076         1  6 Pack Soft Drink             [Coke]     $6.49
#
#       price_float
# 3389        12.98
# 341          6.49
# 1849         6.49
# 1860         6.49
# 2713         6.49

# %% [markdown]
# # what is quantity of most expensive item ordered?

# %%
df2.price_float.idxmax()
# Out:
# 3598

# %%
df2.loc[3598, 'quantity']
# Out:
# 15

# %% [markdown]
# # How many times of veggie salad bowl ordered?

# %%
# (df2.item_name == 'Veggie Salad Bowl').sum()
df2[df2.item_name == 'Veggie Salad Bowl'].quantity.sum()
# Out:
# 18

# %% [markdown]
# # how many times people ordered more than one Canned Soda?

# %%
(df2[df2.item_name == 'Canned Soda'].quantity > 1).sum()
# len(df2[(df2.item_name == 'Canned Soda') & (df2.quantity > 1)])
# Out:
# 20
