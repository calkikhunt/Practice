# %%
import pandas as pd

# %%
df1 = pd.read_csv("addresses.csv")
df1.head()
# Out:
#                     John       Doe                 120 jefferson st.  \
# 0                   Jack  McGinnis                      220 hobo Av.
# 1          John "Da Man"    Repici                 120 Jefferson St.
# 2                Stephen     Tyler  7452 Terrace "At the Plaza" road
# 3                    NaN  Blankman                               NaN
# 4  Joan "the bone", Anne       Jet               9th, at Terrace plc
#
#      Riverside   NJ   08075
# 0        Phila   PA    9119
# 1    Riverside   NJ    8075
# 2     SomeTown   SD   91234
# 3     SomeTown   SD     298
# 4  Desert City   CO     123

# %%
df1 = pd.read_csv("addresses.csv", header=None, skiprows=[0, 1], na_values=['Repici'])
df1.head()
# Out:
#                        0         1                                 2  \
# 0          John "Da Man"       NaN                 120 Jefferson St.
# 1                Stephen     Tyler  7452 Terrace "At the Plaza" road
# 2                    NaN  Blankman                               NaN
# 3  Joan "the bone", Anne       Jet               9th, at Terrace plc
#
#              3    4      5
# 0    Riverside   NJ   8075
# 1     SomeTown   SD  91234
# 2     SomeTown   SD    298
# 3  Desert City   CO    123

# %%
# description function by default always gives you discription of numerical data.
df1.describe()
# Out:
#                   5
# count      4.000000
# mean   24932.500000
# std    44356.262575
# min      123.000000
# 25%      254.250000
# 50%     4186.500000
# 75%    28864.750000
# max    91234.000000

# %%
df1.dtypes
# Out:
# 0    object
# 1    object
# 2    object
# 3    object
# 4    object
# 5     int64
# dtype: object

# %%
df1 = pd.read_csv("addresses.csv", header=None, names=['a','b','c','d','e','f'])
df1
# Out:
#                        a         b                                 c  \
# 0                   John       Doe                 120 jefferson st.
# 1                   Jack  McGinnis                      220 hobo Av.
# 2          John "Da Man"    Repici                 120 Jefferson St.
# 3                Stephen     Tyler  7452 Terrace "At the Plaza" road
# 4                    NaN  Blankman                               NaN
# 5  Joan "the bone", Anne       Jet               9th, at Terrace plc
#
#              d    e      f
# 0    Riverside   NJ   8075
# 1        Phila   PA   9119
# 2    Riverside   NJ   8075
# 3     SomeTown   SD  91234
# 4     SomeTown   SD    298
# 5  Desert City   CO    123

# %%
df1.to_csv("result.csv", index=False, header=False, sep="#", columns=['a', 'b'])
# to remove index and header from csv file
# sep=# to change separator in csv
# columns=[] only add those column which is available in list

# %%
df1.columns
# Out:
# Index(['a', 'b', 'c', 'd', 'e', 'f'], dtype='object')

# %%
df1['a']
# Out:
# 0                     John
# 1                     Jack
# 2            John "Da Man"
# 3                  Stephen
# 4                      NaN
# 5    Joan "the bone", Anne
# Name: a, dtype: object

# %%
# series is nothing but one single record whether its a row record or column record
# in other word its subset of a dataset.
print(type(df1['a']))
print(type(df1[['a']]))
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>

# %%
df2 = pd.read_excel("SampleData.xlsx", sheet_name="SalesOrders")
df2.head()
# sheet_name parameter to read particular sheet
# Out:
#    OrderDate   Region      Rep    Item  Units  Unit Cost   Total
# 0 2021-01-06     East    Jones  Pencil     95       1.99  189.05
# 1 2021-01-23  Central   Kivell  Binder     50      19.99  999.50
# 2 2021-02-09  Central  Jardine  Pencil     36       4.99  179.64
# 3 2021-02-26  Central     Gill     Pen     27      19.99  539.73
# 4 2021-03-15     West  Sorvino  Pencil     56       2.99  167.44

# %%
df3 = pd.read_html("https://www.basketball-reference.com/players/p/paulch01.html")
type(df3)
# Out:
# list

# %%
df3[0].head()
# Out:
#     Season   Age   Tm   Lg Pos     G    GS    MP   FG   FGA  ...    FT%  ORB  \
# 0  2005-06  20.0  NOK  NBA  PG  78.0  78.0  36.0  5.2  12.1  ...  0.847  0.8
# 1  2006-07  21.0  NOK  NBA  PG  64.0  64.0  36.8  6.0  13.6  ...  0.818  0.8
# 2  2007-08  22.0  NOH  NBA  PG  80.0  80.0  37.6  7.9  16.1  ...  0.851  0.8
# 3  2008-09  23.0  NOH  NBA  PG  78.0  78.0  38.5  8.1  16.1  ...  0.868  0.9
# 4  2009-10  24.0  NOH  NBA  PG  45.0  45.0  38.0  7.0  14.2  ...  0.847  0.4
#
#    DRB  TRB   AST  STL  BLK  TOV   PF   PTS
# 0  4.3  5.1   7.8  2.2  0.1  2.3  2.8  16.1
# 1  3.5  4.4   8.9  1.8  0.0  2.5  2.4  17.3
# 2  3.2  4.0  11.6  2.7  0.1  2.5  2.3  21.1
# 3  4.7  5.5  11.0  2.8  0.1  3.0  2.7  22.8
# 4  3.8  4.2  10.7  2.1  0.2  2.5  2.6  18.7
#
# [5 rows x 30 columns]

# %%
pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv").head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
s = """{
    "name": "calki",
    "phone_on": 456789123,
    "comp": ["Tecblic", "Keypress"]
}
"""

# %%
import json
s1 = json.loads(s)

# %%
type(s1)
# Out:
# dict

# %%
pd.DataFrame(s1)
# Out:
#     name   phone_on      comp
# 0  calki  456789123   Tecblic
# 1  calki  456789123  Keypress

# %%
import requests
res = requests.get("https://api.github.com/repos/pandas-dev/pandas/issues")

# %%
js = res.json()

# %%
js[0]['title']
# Out:
# 'DOC: Move general utility functions to better locations'

# %%
df5 = pd.DataFrame(js).head()

# %%
df5.to_csv("json_dump.csv")

# %%
pd.DataFrame(list(df5['user']))
# Out:
#             login         id               node_id  \
# 0       mroeschke   10647082  MDQ6VXNlcjEwNjQ3MDgy
# 1      mach881040  100502242          U_kgDOBf2K4g
# 2    jbrockmendel    8078968  MDQ6VXNlcjgwNzg5Njg=
# 3  fractionalhare   10540830  MDQ6VXNlcjEwNTQwODMw
# 4        macsakow   10297014  MDQ6VXNlcjEwMjk3MDE0
#
#                                           avatar_url gravatar_id  \
# 0  https://avatars.githubusercontent.com/u/106470...
# 1  https://avatars.githubusercontent.com/u/100502...
# 2  https://avatars.githubusercontent.com/u/807896...
# 3  https://avatars.githubusercontent.com/u/105408...
# 4  https://avatars.githubusercontent.com/u/102970...
#
#                                            url  \
# 0       https://api.github.com/users/mroeschke
# 1      https://api.github.com/users/mach881040
# 2    https://api.github.com/users/jbrockmendel
# 3  https://api.github.com/users/fractionalhare
# 4        https://api.github.com/users/macsakow
#
# ...

# %%
q = pd.read_json("https://api.github.com/repos/pandas-dev/pandas/issues")
data = pd.DataFrame(list(q['user']))
data.head()
# Out:
#             login         id               node_id  \
# 0       mroeschke   10647082  MDQ6VXNlcjEwNjQ3MDgy
# 1      mach881040  100502242          U_kgDOBf2K4g
# 2    jbrockmendel    8078968  MDQ6VXNlcjgwNzg5Njg=
# 3  fractionalhare   10540830  MDQ6VXNlcjEwNTQwODMw
# 4        macsakow   10297014  MDQ6VXNlcjEwMjk3MDE0
#
#                                           avatar_url gravatar_id  \
# 0  https://avatars.githubusercontent.com/u/106470...
# 1  https://avatars.githubusercontent.com/u/100502...
# 2  https://avatars.githubusercontent.com/u/807896...
# 3  https://avatars.githubusercontent.com/u/105408...
# 4  https://avatars.githubusercontent.com/u/102970...
#
#                                            url  \
# 0       https://api.github.com/users/mroeschke
# 1      https://api.github.com/users/mach881040
# 2    https://api.github.com/users/jbrockmendel
# 3  https://api.github.com/users/fractionalhare
# 4        https://api.github.com/users/macsakow
#
# ...

# %%
# pickle file format is one of the binary file format in which it can try to store the data by 
# serializing file and store that data to object.
# Pickle in python is primarily used in serializing and deserializing a Python object structure. in other 
# words, its the process of converting a python object into byte stream to store in a file/database, maintain
# program state across sessions, or transport data over the network.
# serializing = obj to bytecode
# deserializing = bytecode to obj
df2.to_pickle("my_pickle")

# %%
h5_data = pd.HDFStore("test.h5")

# %%
h5_data["obj1"] = df2
h5_data["obj1"].head()
# Out:
#    OrderDate   Region      Rep    Item  Units  Unit Cost   Total
# 0 2021-01-06     East    Jones  Pencil     95       1.99  189.05
# 1 2021-01-23  Central   Kivell  Binder     50      19.99  999.50
# 2 2021-02-09  Central  Jardine  Pencil     36       4.99  179.64
# 3 2021-02-26  Central     Gill     Pen     27      19.99  539.73
# 4 2021-03-15     West  Sorvino  Pencil     56       2.99  167.44

# %%
h5_data.put('obj2', data, format='table')

# %%
h5_data.select('obj2', where=['index >= 10 and index <= 15'])
# Out:
#          login        id               node_id  \
# 10  lukemanley   8519523  MDQ6VXNlcjg1MTk1MjM=
# 11     weikhor  36619387  MDQ6VXNlcjM2NjE5Mzg3
# 12  lukemanley   8519523  MDQ6VXNlcjg1MTk1MjM=
# 13    milotoor   4667801  MDQ6VXNlcjQ2Njc4MDE=
# 14    tehunter   7980666  MDQ6VXNlcjc5ODA2NjY=
# 15  jukiewiczm   8179126  MDQ6VXNlcjgxNzkxMjY=
#
#                                            avatar_url gravatar_id  \
# 10  https://avatars.githubusercontent.com/u/851952...
# 11  https://avatars.githubusercontent.com/u/366193...
# 12  https://avatars.githubusercontent.com/u/851952...
# 13  https://avatars.githubusercontent.com/u/466780...
# 14  https://avatars.githubusercontent.com/u/798066...
# 15  https://avatars.githubusercontent.com/u/817912...
#
#                                         url                       html_url  \
# 10  https://api.github.com/users/lukemanley  https://github.com/lukemanley
# 11     https://api.github.com/users/weikhor     https://github.com/weikhor
# ...

# %%
type(h5_data)
# Out:
# pandas.io.pytables.HDFStore

# %%
df6 = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")
df6.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df6.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df7 = df6[df6.dtypes[df6.dtypes == 'object'].index].head()

# %%
# two type of columns are available in DataFrame nuemerical and categorical.
df6["Ticket"][5:15]
# Out:
# 5        330877
# 6         17463
# 7        349909
# 8        347742
# 9        237736
# 10      PP 9549
# 11       113783
# 12    A/5. 2151
# 13       347082
# 14       350406
# Name: Ticket, dtype: object

# %%
df6.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df7['name'] = 'kalkivi'
df7
# Out:
#                                                 Name     Sex  \
# 0                            Braund, Mr. Owen Harris    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                           Allen, Mr. William Henry    male
#
#              Ticket Cabin Embarked     name
# 0         A/5 21171   NaN        S  kalkivi
# 1          PC 17599   C85        C  kalkivi
# 2  STON/O2. 3101282   NaN        S  kalkivi
# 3            113803  C123        S  kalkivi
# 4            373450   NaN        S  kalkivi

# %%
pd.Categorical(df7['Embarked'])
# Out:
# ['S', 'C', 'S', 'S', 'S']
# Categories (2, object): ['C', 'S']

# %%
df7['Embarked'].unique()
# Out:
# array(['S', 'C'], dtype=object)

# %%
x = df6['Age'][df6['Age'].isnull() == True].index

# %%
df6.iloc[x].head()
# Out:
#     PassengerId  Survived  Pclass                           Name     Sex  Age  \
# 5             6         0       3               Moran, Mr. James    male  NaN
# 17           18         1       2   Williams, Mr. Charles Eugene    male  NaN
# 19           20         1       3        Masselmani, Mrs. Fatima  female  NaN
# 26           27         0       3        Emir, Mr. Farred Chehab    male  NaN
# 28           29         1       3  O'Dwyer, Miss. Ellen "Nellie"  female  NaN
#
#     SibSp  Parch  Ticket     Fare Cabin Embarked
# 5       0      0  330877   8.4583   NaN        Q
# 17      0      0  244373  13.0000   NaN        S
# 19      0      0    2649   7.2250   NaN        C
# 26      0      0    2631   7.2250   NaN        C
# 28      0      0  330959   7.8792   NaN        Q

# %%
y = df6['Cabin'][df6['Cabin'].isnull() == False].index
df6.iloc[y].head()
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 6             7         0       1
# 10           11         1       3
# 11           12         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
#
#     Parch    Ticket     Fare Cabin Embarked
# 1       0  PC 17599  71.2833   C85        C
# 3       0    113803  53.1000  C123        S
# 6       0     17463  51.8625   E46        S
# 10      1   PP 9549  16.7000    G6        S
# 11      0    113783  26.5500  C103        S

# %%
df6[df6['Fare'] == df6['Fare'].max()]['Name']
# Out:
# 258                      Ward, Miss. Anna
# 679    Cardeza, Mr. Thomas Drake Martinez
# 737                Lesurer, Mr. Gustave J
# Name: Name, dtype: object

# %%
df6['Pnew'] = df6['PassengerId'] + df6['Pclass']

# %%
df6.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Pnew
# 0      0         A/5 21171   7.2500   NaN        S     4
# 1      0          PC 17599  71.2833   C85        C     3
# 2      0  STON/O2. 3101282   7.9250   NaN        S     6
# 3      0            113803  53.1000  C123        S     5
# ...

# %%
df7 = pd.read_table("https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv")
df7.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_table("https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB

# %%
df.shape[0]
# Out:
# 4622

# %%
df.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %%
a = df.groupby('item_name')['quantity'].sum()
a = a.sort_values()
a.tail(1)
# Out:
# item_name
# Chicken Bowl    761
# Name: quantity, dtype: int64

# %%
df.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
b = df.groupby("choice_description")['quantity'].sum()
b = b.sort_values()
b.tail(1)
# Out:
# choice_description
# [Diet Coke]    159
# Name: quantity, dtype: int64

# %%
(df['quantity'] * df['item_price']).sum()
# Out:
# 39237.02

# %%
df['quantity'] * df['item_price']
# Out:
# 0        2.39
# 1        3.39
# 2        3.39
# 3        2.39
# 4       33.96
#         ...
# 4617    11.75
# 4618    11.75
# 4619    11.25
# 4620     8.75
# 4621     8.75
# Length: 4622, dtype: float64

# %%
url = 'https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/04_Apply/US_Crime_Rates/US_Crime_Rates_1960_2014.csv'
df = pd.read_csv(url)
df.head()
# Out:
#    Year  Population    Total  Violent  Property  Murder  Forcible_Rape  \
# 0  1960   179323175  3384200   288460   3095700    9110          17190
# 1  1961   182992000  3488000   289390   3198600    8740          17220
# 2  1962   185771000  3752200   301510   3450700    8530          17550
# 3  1963   188483000  4109500   316970   3792500    8640          17650
# 4  1964   191141000  4564600   364220   4200400    9360          21420
#
#    Robbery  Aggravated_assault  Burglary  Larceny_Theft  Vehicle_Theft
# 0   107840              154320    912100        1855400         328200
# 1   106670              156760    949600        1913000         336000
# 2   110860              164570    994300        2089600         366800
# 3   116470              174210   1086400        2297800         408300
# 4   130390              203050   1213200        2514400         472800

# %%
df.Year = pd.to_datetime(df.Year, format='%Y')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Year                55 non-null     datetime64[ns]
#  1   Population          55 non-null     int64
#  2   Total               55 non-null     int64
#  3   Violent             55 non-null     int64
#  4   Property            55 non-null     int64
#  5   Murder              55 non-null     int64
#  6   Forcible_Rape       55 non-null     int64
#  7   Robbery             55 non-null     int64
#  8   Aggravated_assault  55 non-null     int64
#  9   Burglary            55 non-null     int64
#  10  Larceny_Theft       55 non-null     int64
#  11  Vehicle_Theft       55 non-null     int64
# dtypes: datetime64[ns](1), int64(11)
# memory usage: 5.3 KB

# %%
df = df.set_index('Year', drop = True)
df.head()
# Out:
#             Population    Total  Violent  Property  Murder  Forcible_Rape  \
# Year
# 1960-01-01   179323175  3384200   288460   3095700    9110          17190
# 1961-01-01   182992000  3488000   289390   3198600    8740          17220
# 1962-01-01   185771000  3752200   301510   3450700    8530          17550
# 1963-01-01   188483000  4109500   316970   3792500    8640          17650
# 1964-01-01   191141000  4564600   364220   4200400    9360          21420
#
#             Robbery  Aggravated_assault  Burglary  Larceny_Theft  \
# Year
# 1960-01-01   107840              154320    912100        1855400
# 1961-01-01   106670              156760    949600        1913000
# 1962-01-01   110860              164570    994300        2089600
# 1963-01-01   116470              174210   1086400        2297800
# 1964-01-01   130390              203050   1213200        2514400
#
#             Vehicle_Theft
# Year
# 1960-01-01         328200
# 1961-01-01         336000
# ...

# %%
df2 = df.resample('10AS').sum()
Population = df['Population'].resample('10AS').max()
df2['Population'] = Population
df2.head()
# Out:
#             Population      Total   Violent   Property  Murder  Forcible_Rape  \
# Year
# 1960-01-01   201385000   49295900   4134930   45160900  106180         236720
# 1970-01-01   220099000  100991600   9607930   91383800  192230         554570
# 1980-01-01   248239000  131123369  14074328  117048900  206439         865639
# 1990-01-01   272690813  136582146  17527048  119053499  211664         998827
# 2000-01-01   307006550  115012044  13968056  100944369  163068         922499
#
#             Robbery  Aggravated_assault  Burglary  Larceny_Theft  \
# Year
# 1960-01-01  1633510             2158520  13321100       26547700
# 1970-01-01  4159020             4702120  28486000       53157800
# 1980-01-01  5383109             7619130  33073494       72040253
# 1990-01-01  5748930            10568963  26750015       77679366
# 2000-01-01  4230366             8652124  21565176       67970291
#
#             Vehicle_Theft
# Year
# 1960-01-01        5292100
# 1970-01-01        9739900
# ...

# %%
df.iloc[:3]
# Out:
#             Population    Total  Violent  Property  Murder  Forcible_Rape  \
# Year
# 1960-01-01   179323175  3384200   288460   3095700    9110          17190
# 1961-01-01   182992000  3488000   289390   3198600    8740          17220
# 1962-01-01   185771000  3752200   301510   3450700    8530          17550
#
#             Robbery  Aggravated_assault  Burglary  Larceny_Theft  \
# Year
# 1960-01-01   107840              154320    912100        1855400
# 1961-01-01   106670              156760    949600        1913000
# 1962-01-01   110860              164570    994300        2089600
#
#             Vehicle_Theft
# Year
# 1960-01-01         328200
# 1961-01-01         336000
# 1962-01-01         366800

# %%
df.loc[:, ['Murder', 'Robbery']].head()
# Out:
#             Murder  Robbery
# Year
# 1960-01-01    9110   107840
# 1961-01-01    8740   106670
# 1962-01-01    8530   110860
# 1963-01-01    8640   116470
# 1964-01-01    9360   130390

# %%
df[['Murder', 'Robbery']].head()
# Out:
#             Murder  Robbery
# Year
# 1960-01-01    9110   107840
# 1961-01-01    8740   106670
# 1962-01-01    8530   110860
# 1963-01-01    8640   116470
# 1964-01-01    9360   130390

# %%
df.loc[df.index[[3, 4, 8]], ['Murder', 'Robbery']]
# Out:
#             Murder  Robbery
# Year
# 1963-01-01    8640   116470
# 1964-01-01    9360   130390
# 1968-01-01   13800   262840

# %%
df[df['Murder'] > 24000]
# Out:
#             Population     Total  Violent  Property  Murder  Forcible_Rape  \
# Year
# 1991-01-01   252177000  14872900  1911770  12961100   24700         106590
# 1993-01-01   257908000  14144800  1926020  12218800   24530         106010
#
#             Robbery  Aggravated_assault  Burglary  Larceny_Theft  \
# Year
# 1991-01-01   687730             1092740   3157200        8142200
# 1993-01-01   659870             1135610   2834800        7820900
#
#             Vehicle_Theft
# Year
# 1991-01-01        1661700
# 1993-01-01        1563100

# %%
# df[(df['Murder'] >= 20000) & (df['Murder'] <= 24000)]
df[df['Murder'].between(20000, 24000)].head()
# Out:
#             Population     Total  Violent  Property  Murder  Forcible_Rape  \
# Year
# 1974-01-01   211392000  10253400   974720   9278700   20710          55400
# 1975-01-01   213124000  11292400  1039710  10252700   20510          56090
# 1979-01-01   220099000  12249500  1208030  11041500   21460          76390
# 1980-01-01   225349264  13408300  1344520  12063700   23040          82990
# 1981-01-01   229146000  13423800  1361820  12061900   22520          82500
#
#             Robbery  Aggravated_assault  Burglary  Larceny_Theft  \
# Year
# 1974-01-01   442400              456210   3039200        5262500
# 1975-01-01   470500              492620   3265300        5977700
# 1979-01-01   480700              629480   3327700        6601000
# 1980-01-01   565840              672650   3795200        7136900
# 1981-01-01   592910              663900   3779700        7194400
#
#             Vehicle_Theft
# Year
# 1974-01-01         977100
# 1975-01-01        1009600
# ...

# %%
df.head()
# Out:
#             Population    Total  Violent  Property  Murder  Forcible_Rape  \
# Year
# 1960-01-01   179323175  3384200   288460   3095700    9110          17190
# 1961-01-01   182992000  3488000   289390   3198600    8740          17220
# 1962-01-01   185771000  3752200   301510   3450700    8530          17550
# 1963-01-01   188483000  4109500   316970   3792500    8640          17650
# 1964-01-01   191141000  4564600   364220   4200400    9360          21420
#
#             Robbery  Aggravated_assault  Burglary  Larceny_Theft  \
# Year
# 1960-01-01   107840              154320    912100        1855400
# 1961-01-01   106670              156760    949600        1913000
# 1962-01-01   110860              164570    994300        2089600
# 1963-01-01   116470              174210   1086400        2297800
# 1964-01-01   130390              203050   1213200        2514400
#
#             Vehicle_Theft
# Year
# 1960-01-01         328200
# 1961-01-01         336000
# ...

# %%
df.groupby('Year')['Murder'].mean().head()
# Out:
# Year
# 1960-01-01    9110.0
# 1961-01-01    8740.0
# 1962-01-01    8530.0
# 1963-01-01    8640.0
# 1964-01-01    9360.0
# Name: Murder, dtype: float64

# %%
df.sort_values(by=['Murder', 'Violent'], ascending=[False, True]).head()
# Out:
#             Population     Total  Violent  Property  Murder  Forcible_Rape  \
# Year
# 1991-01-01   252177000  14872900  1911770  12961100   24700         106590
# 1993-01-01   257908000  14144800  1926020  12218800   24530         106010
# 1992-01-01   255082000  14438200  1932270  12505900   23760         109060
# 1990-01-01   248709873  14475600  1820130  12655500   23440         102560
# 1994-01-01   260341000  13989500  1857670  12131900   23330         102220
#
#             Robbery  Aggravated_assault  Burglary  Larceny_Theft  \
# Year
# 1991-01-01   687730             1092740   3157200        8142200
# 1993-01-01   659870             1135610   2834800        7820900
# 1992-01-01   672480             1126970   2979900        7915200
# 1990-01-01   639270             1054860   3073900        7945700
# 1994-01-01   618950             1113180   2712800        7879800
#
#             Vehicle_Theft
# Year
# 1991-01-01        1661700
# 1993-01-01        1563100
# ...
