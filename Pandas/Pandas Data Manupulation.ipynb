# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
np.random.seed(20)
df = pd.DataFrame(
    np.random.rand(1000, 1), 
    index=pd.date_range("2022-07-25", periods=1000),
    columns=['data']
)
df
# Out:
#                 data
# 2022-07-25  0.588131
# 2022-07-26  0.897714
# 2022-07-27  0.891531
# 2022-07-28  0.815837
# 2022-07-29  0.035890
# ...              ...
# 2025-04-15  0.992189
# 2025-04-16  0.756037
# 2025-04-17  0.299186
# 2025-04-18  0.261712
# 2025-04-19  0.968979
#
# [1000 rows x 1 columns]

# %%
plt.plot(df)

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df["data1"] = df.data.cumsum()

# %%
df["data2"] = df["data"].apply(lambda l:l*3)

# %%
df.plot(figsize=(10, 10))
# Out:
# <AxesSubplot:>

# %%
df1 = sns.load_dataset('iris')

# %%
a = df1.plot(figsize=(5, 5), title="iris")
a.set_xlabel("x")
a.set_ylabel("y")
# Out:
# Text(0, 0.5, 'y')

# %%
df1.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df1.iloc[0][:4].plot()
# Out:
# <AxesSubplot:>

# %%
df1.iloc[0][:4].plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
df2 = sns.load_dataset("titanic")
df2.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df2["pclass"].plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
df3 = pd.DataFrame(np.random.rand(10, 4), columns=["a","b","c","d"])
df3
# Out:
#           a         b         c         d
# 0  0.754462  0.591334  0.108692  0.402853
# 1  0.269676  0.573075  0.916855  0.189785
# 2  0.944349  0.820192  0.229638  0.697904
# 3  0.701251  0.570189  0.448045  0.332812
# 4  0.108018  0.121464  0.420368  0.336497
# 5  0.389588  0.301919  0.312265  0.036205
# 6  0.378922  0.010581  0.357048  0.083158
# 7  0.705395  0.816193  0.262531  0.382466
# 8  0.897100  0.437109  0.842188  0.852225
# 9  0.123356  0.150039  0.214021  0.006917

# %%
df3.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df3.plot.barh()
# Out:
# <AxesSubplot:>

# %%
df1.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df1.plot(kind="hist", stacked=True, bins=100, figsize=(10, 10), orientation="horizontal")
# Out:
# <AxesSubplot:xlabel='Frequency'>

# %%
df1.hist(figsize=(10, 10), color="#FF5733", alpha=.5)
# alpha used for opacity
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %%
df1.plot.scatter(x="sepal_width",y="petal_width")
# Out:
# <AxesSubplot:xlabel='sepal_width', ylabel='petal_width'>

# %%
df1.plot.scatter(x="sepal_width",y="petal_length", c="sepal_length")
# Out:
# <AxesSubplot:xlabel='sepal_width', ylabel='petal_length'>

# %%
df1.plot.scatter(x="sepal_length", y="sepal_width", label="calki", s=100, c="petal_width")
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
df1.plot.hexbin(x="sepal_length", y="sepal_width", label="calki", gridsize=10, C="petal_width")
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
d = df.iloc[0]

# %%
d.plot.pie()
# Out:
# <AxesSubplot:ylabel='2022-07-25 00:00:00'>

# %%
i = df1.head(3).T

# %%
i.iloc[:4].plot.pie(subplots=True, figsize=(20, 20), autopct="%.2f", fontsize=15)
# Out:
# array([<AxesSubplot:ylabel='0'>, <AxesSubplot:ylabel='1'>,
#        <AxesSubplot:ylabel='2'>], dtype=object)

# %%
pd.plotting.scatter_matrix(df1, figsize=(10,10))
# Out:
# array([[<AxesSubplot:xlabel='sepal_length', ylabel='sepal_length'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='sepal_length'>,
#         <AxesSubplot:xlabel='petal_length', ylabel='sepal_length'>,
#         <AxesSubplot:xlabel='petal_width', ylabel='sepal_length'>],
#        [<AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='sepal_width'>,
#         <AxesSubplot:xlabel='petal_length', ylabel='sepal_width'>,
#         <AxesSubplot:xlabel='petal_width', ylabel='sepal_width'>],
#        [<AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='petal_length'>,
#         <AxesSubplot:xlabel='petal_length', ylabel='petal_length'>,
#         <AxesSubplot:xlabel='petal_width', ylabel='petal_length'>],
#        [<AxesSubplot:xlabel='sepal_length', ylabel='petal_width'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='petal_width'>,
# ...

# %%
pd.plotting.scatter_matrix(df1, figsize=(10,10), diagonal="kde")
# Out:
# array([[<AxesSubplot:xlabel='sepal_length', ylabel='sepal_length'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='sepal_length'>,
#         <AxesSubplot:xlabel='petal_length', ylabel='sepal_length'>,
#         <AxesSubplot:xlabel='petal_width', ylabel='sepal_length'>],
#        [<AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='sepal_width'>,
#         <AxesSubplot:xlabel='petal_length', ylabel='sepal_width'>,
#         <AxesSubplot:xlabel='petal_width', ylabel='sepal_width'>],
#        [<AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='petal_length'>,
#         <AxesSubplot:xlabel='petal_length', ylabel='petal_length'>,
#         <AxesSubplot:xlabel='petal_width', ylabel='petal_length'>],
#        [<AxesSubplot:xlabel='sepal_length', ylabel='petal_width'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='petal_width'>,
# ...

# %%
df["data"].plot(style="r*", legend=True, label="calki")
# Out:
# <AxesSubplot:>

# %%
df["data"].plot(style="r--", legend=True, label="calki")
# Out:
# <AxesSubplot:>
